# %%
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re
import json
import string

# %%
label=list(string.ascii_lowercase)
page=list(range(1,500))
URLS=[]
for i in label:
    for j in page:
        URLS.append("https://www.1mg.com/drugs-all-medicines?page="+str(j)+"&label="+i)

# %%
len(URLS)
# Out:
# 1039974

# %% [markdown]
# ### Strategy for scraping
#
# - All of the required data is contained in a script tag which begins with the text "window.__INITIAL_STATE__"
#
# - First I have extracted all script tags from the soup
#
# - Then I have extracted the required script tag (by checking if it begins with the "window.__INITIAL_STATE__" text)
#
# - Then I perform a bit of cleaning before loading the required data as json

# %% [markdown]
# Note - Each of the script tags only contain 20 of the items even though we see 30 items per page. But the remaining items are available by making requests to the next page

# %%
def extract_json(soup):
    all_scripts=soup.find_all("script")
    
    #extracting the script tag as a string (storing in a list)
    all_med_data=[]
    for script in all_scripts:
        # to check if a script tag can be converted to a string and if the string has the "window.__INITIAL__STATE__"
        if (script.string) and ("window.__INITIAL_STATE__" in script.string):
            all_med_data.append(script.string)
    json_data=all_med_data[0].replace("\n    window.__INITIAL_STATE__ = ",""
                       ).replace(";\n    window.__STATUS_CODE__ = null;\n","")
    json_data=json.loads(json_data)
    
    return(json_data['allMedicinePageReducer']['data'])

# %%
# %%time
soup=[]
for i in URLS[1:2]:
    try:
        page_req=requests.get(i)
        soup.append(BeautifulSoup(page_req.content, "html.parser"))
        print("present")
    except:
        print(f"URL not present{i}")
# Out:
# present
# Wall time: 298 ms

# %%
extract_json(soup)
# Out:
# {'skus': [{'is_discontinued': False,
#    'manufacturer_name': 'Pfizer Ltd',
#    'type': 'allopathy',
#    'price': 82.99,
#    'name': 'Ativan 2mg Tablet',
#    'id': 236513,
#    'sku_id': 236513,
#    'available': False,
#    'pack_size_label': 'strip of 30 tablets',
#    'rx_required': {'header': 'Prescription Required',
#     'icon_url': 'https://onemg.gumlet.io/image/upload/w_20,h_20/q_auto,f_auto/rx_icon.png'},
#    'slug': '/drugs/ativan-2mg-tablet-236513',
#    'short_composition': 'Lorazepam (2mg)',
#    'image_url': 'https://onemg.gumlet.io/image/upload/a_ignore,w_380,h_380,c_fit,q_auto,f_auto/v1625228213/hx2gxivwmeoxxxsc1hix.png',
#    'in_stock': None,
#    'quantity': 30},
#   {'is_discontinued': False,
#    'manufacturer_name': 'Glenmark Pharmaceuticals Ltd',
#    'type': 'allopathy',
#    'price': 118,
#    'name': 'Ascoril D Plus Syrup Sugar Free',
#    'id': 184611,
#    'sku_id': 184611,
#    'available': True,
#    'pack_size_label': 'bottle of 100 ml Syrup',
#    'rx_required': {'header': 'Prescription Required',
#     'icon_url': 'https://onemg.gumlet.io/image/upload/w_20,h_20/q_auto,f_auto/rx_icon.png'},
#    'slug': '/drugs/ascoril-d-plus-syrup-sugar-free-184611',
#    'short_composition': 'Phenylephrine (5mg) + Chlorpheniramine Maleate (2mg) + Dextromethorphan Hydrobromide (10mg)',
#    'image_url': 'https://onemg.gumlet.io/image/upload/a_ignore,w_380,h_380,c_fit,q_auto,f_auto/v1527057821/la9aelaydysxuaizrcd5.jpg',
#    'in_stock': {'add': {'action_label': 'Adding..',
#      'final_label': 'ADDED',
#      'label': 'ADD'},
#     'cart_actions': {'dweb': ['add'], 'mweb': ['add']}},
#    'quantity': 1},
#   {'is_discontinued': False,
#    'manufacturer_name': 'Torrent Pharmaceuticals Ltd',
#    'type': 'allopathy',
#    'price': 60.85,
#    'name': 'Alprax 0.5mg Tablet SR',
#    'id': 68773,
#    'sku_id': 68773,
#    'available': False,
#    'pack_size_label': 'strip of 15 tablet sr',
#    'rx_required': {'header': 'Prescription Required',
#     'icon_url': 'https://onemg.gumlet.io/image/upload/w_20,h_20/q_auto,f_auto/rx_icon.png'},
#    'slug': '/drugs/alprax-0.5mg-tablet-sr-68773',
#    'short_composition': 'Alprazolam (0.5mg)',
#    'image_url': 'https://onemg.gumlet.io/image/upload/a_ignore,w_380,h_380,c_fit,q_auto,f_auto/v1625228213/hx2gxivwmeoxxxsc1hix.png',
#    'in_stock': None,
#    'quantity': 15},
#   {'is_discontinued': False,
#    'manufacturer_name': 'Pfizer Ltd',
#    'type': 'allopathy',
#    'price': 68.36,
#    'name': 'Ativan 1mg Tablet',
#    'id': 322827,
#    'sku_id': 322827,
#    'available': False,
#    'pack_size_label': 'strip of 30 tablets',
#    'rx_required': {'header': 'Prescription Required',
#     'icon_url': 'https://onemg.gumlet.io/image/upload/w_20,h_20/q_auto,f_auto/rx_icon.png'},
#    'slug': '/drugs/ativan-1mg-tablet-322827',
#    'short_composition': 'Lorazepam (1mg)',
#    'image_url': 'https://onemg.gumlet.io/image/upload/a_ignore,w_380,h_380,c_fit,q_auto,f_auto/v1625228213/hx2gxivwmeoxxxsc1hix.png',
#    'in_stock': None,
#    'quantity': 30},
#   {'is_discontinued': False,
#    'manufacturer_name': "Dr Reddy's Laboratories Ltd",
#    'type': 'allopathy',
#    'price': 43.56,
#    'name': 'Atarax 10mg Tablet',
#    'id': 228392,
#    'sku_id': 228392,
#    'available': True,
#    'pack_size_label': 'strip of 15 tablets',
#    'rx_required': {'header': 'Prescription Required',
#     'icon_url': 'https://onemg.gumlet.io/image/upload/w_20,h_20/q_auto,f_auto/rx_icon.png'},
#    'slug': '/drugs/atarax-10mg-tablet-228392',
#    'short_composition': 'Hydroxyzine (10mg)',
#    'image_url': 'https://onemg.gumlet.io/image/upload/a_ignore,w_380,h_380,c_fit,q_auto,f_auto/v1625228213/hx2gxivwmeoxxxsc1hix.png',
#    'in_stock': {'add': {'action_label': 'Adding..',
#      'final_label': 'ADDED',
#      'label': 'ADD'},
#     'cart_actions': {'dweb': ['add'], 'mweb': ['add']}},
#    'quantity': 15},
#   {'is_discontinued': False,
#    'manufacturer_name': 'Sun Pharmaceutical Industries Ltd',
#    'type': 'allopathy',
#    'price': 120,
#    'name': 'Altraday Capsule SR',
#    'id': 63221,
#    'sku_id': 63221,
#    'available': True,
#    'pack_size_label': 'strip of 10 capsule sr',
#    'rx_required': {'header': 'Prescription Required',
#     'icon_url': 'https://onemg.gumlet.io/image/upload/w_20,h_20/q_auto,f_auto/rx_icon.png'},
#    'slug': '/drugs/altraday-capsule-sr-63221',
#    'short_composition': 'Aceclofenac (200mg) + Rabeprazole (20mg)',
#    'image_url': 'https://onemg.gumlet.io/image/upload/a_ignore,w_380,h_380,c_fit,q_auto,f_auto/v1537710606/tqux8ccp05qx3npvxex9.jpg',
#    'in_stock': {'add': {'action_label': 'Adding..',
#      'final_label': 'ADDED',
#      'label': 'ADD'},
#     'cart_actions': {'dweb': ['add'], 'mweb': ['add']}},
#    'quantity': 10},
#   {'is_discontinued': False,
#    'manufacturer_name': 'RPG Life Sciences Ltd',
#    'type': 'allopathy',
#    'price': 31.95,
#    'name': 'Aldactone Tablet',
#    'id': 116839,
#    'sku_id': 116839,
#    'available': True,
#    'pack_size_label': 'strip of 15 tablets',
#    'rx_required': {'header': 'Prescription Required',
#     'icon_url': 'https://onemg.gumlet.io/image/upload/w_20,h_20/q_auto,f_auto/rx_icon.png'},
#    'slug': '/drugs/aldactone-tablet-116839',
#    'short_composition': 'Spironolactone (25mg)',
#    'image_url': 'https://onemg.gumlet.io/image/upload/a_ignore,w_380,h_380,c_fit,q_auto,f_auto/v1537762262/wxjxsugwqsf4khtkerag.jpg',
#    'in_stock': {'add': {'action_label': 'Adding..',
#      'final_label': 'ADDED',
#      'label': 'ADD'},
#     'cart_actions': {'dweb': ['add'], 'mweb': ['add']}},
#    'quantity': 15},
#   {'is_discontinued': False,
#    'manufacturer_name': 'Cipla Ltd',
#    'type': 'allopathy',
#    'price': 142.51,
#    'name': 'Asthalin 100mcg Inhaler',
#    'id': 141944,
#    'sku_id': 141944,
#    'available': True,
#    'pack_size_label': 'packet of 200 MDI Inhaler',
#    'rx_required': {'header': 'Prescription Required',
#     'icon_url': 'https://onemg.gumlet.io/image/upload/w_20,h_20/q_auto,f_auto/rx_icon.png'},
#    'slug': '/drugs/asthalin-100mcg-inhaler-141944',
#    'short_composition': 'Salbutamol (100mcg)',
#    'image_url': 'https://onemg.gumlet.io/image/upload/a_ignore,w_380,h_380,c_fit,q_auto,f_auto/v1534916806/bznpbcdsc9ae6rw5er6k.jpg',
#    'in_stock': {'add': {'action_label': 'Adding..',
#      'final_label': 'ADDED',
#      'label': 'ADD'},
#     'cart_actions': {'dweb': ['add'], 'mweb': ['add']}},
#    'quantity': 1},
#   {'is_discontinued': False,
#    'manufacturer_name': 'Sanofi India  Ltd',
#    'type': 'allopathy',
#    'price': 188.78,
#    'name': 'Allegra Suspension Raspberry & Vanilla',
#    'id': 114550,
#    'sku_id': 114550,
#    'available': True,
#    'pack_size_label': 'bottle of 100 ml Oral Suspension',
#    'rx_required': {'header': 'Prescription Required',
#     'icon_url': 'https://onemg.gumlet.io/image/upload/w_20,h_20/q_auto,f_auto/rx_icon.png'},
#    'slug': '/drugs/allegra-suspension-raspberry-vanilla-114550',
#    'short_composition': 'Fexofenadine (30mg/5ml)',
#    'image_url': 'https://onemg.gumlet.io/image/upload/a_ignore,w_380,h_380,c_fit,q_auto,f_auto/v1583498876/st6wolbj21wbl4ckon3g.jpg',
#    'in_stock': {'add': {'action_label': 'Adding..',
#      'final_label': 'ADDED',
#      'label': 'ADD'},
#     'cart_actions': {'dweb': ['add'], 'mweb': ['add']}},
#    'quantity': 1},
#   {'is_discontinued': False,
#    'manufacturer_name': 'Sun Pharmaceutical Industries Ltd',
#    'type': 'allopathy',
#    'price': 420,
#    'name': 'Axcer  90mg Tablet',
#    'id': 324040,
#    'sku_id': 324040,
#    'available': True,
#    'pack_size_label': 'strip of 14 tablets',
#    'rx_required': {'header': 'Prescription Required',
#     'icon_url': 'https://onemg.gumlet.io/image/upload/w_20,h_20/q_auto,f_auto/rx_icon.png'},
#    'slug': '/drugs/axcer-90mg-tablet-324040',
#    'short_composition': 'Ticagrelor (90mg)',
#    'image_url': 'https://onemg.gumlet.io/image/upload/a_ignore,w_380,h_380,c_fit,q_auto,f_auto/v1535629110/xewhk7iu0vmvlqmk1oha.jpg',
#    'in_stock': {'add': {'action_label': 'Adding..',
#      'final_label': 'ADDED',
#      'label': 'ADD'},
#     'cart_actions': {'dweb': ['add'], 'mweb': ['add']}},
#    'quantity': 14},
#   {'is_discontinued': True,
#    'manufacturer_name': 'Cadila Pharmaceuticals Ltd',
#    'type': 'allopathy',
#    'price': 42.7,
#    'name': 'Aciloc RD 20 Tablet',
#    'id': 285033,
#    'sku_id': 285033,
#    'available': False,
#    'pack_size_label': 'strip of 10 tablets',
#    'rx_required': {'header': 'Prescription Required',
#     'icon_url': 'https://onemg.gumlet.io/image/upload/w_20,h_20/q_auto,f_auto/rx_icon.png'},
#    'slug': '/drugs/aciloc-rd-20-tablet-285033',
#    'short_composition': 'Domperidone (10mg) + Omeprazole (20mg)',
#    'image_url': 'https://onemg.gumlet.io/image/upload/a_ignore,w_380,h_380,c_fit,q_auto,f_auto/v1528455554/fkwowuw6y6t81jsfqtx0.jpg',
#    'in_stock': None,
#    'quantity': 10},
#   {'is_discontinued': False,
#    'manufacturer_name': 'Alkem Laboratories Ltd',
#    'type': 'allopathy',
#    'price': 115,
#    'name': 'Aldigesic-SP Tablet',
#    'id': 146166,
#    'sku_id': 146166,
#    'available': True,
#    'pack_size_label': 'strip of 10 tablets',
#    'rx_required': {'header': 'Prescription Required',
#     'icon_url': 'https://onemg.gumlet.io/image/upload/w_20,h_20/q_auto,f_auto/rx_icon.png'},
#    'slug': '/drugs/aldigesic-sp-tablet-146166',
#    'short_composition': 'Aceclofenac (100mg) + Paracetamol (325mg) + Serratiopeptidase (10mg)',
#    'image_url': 'https://onemg.gumlet.io/image/upload/a_ignore,w_380,h_380,c_fit,q_auto,f_auto/v1621253290/lyjv1ia5lgikom1diwa4.jpg',
#    'in_stock': {'add': {'action_label': 'Adding..',
#      'final_label': 'ADDED',
#      'label': 'ADD'},
#     'cart_actions': {'dweb': ['add'], 'mweb': ['add']}},
#    'quantity': 10},
#   {'is_discontinued': False,
#    'manufacturer_name': 'Mankind Pharma Ltd',
#    'type': 'allopathy',
#    'price': 64,
#    'name': 'Asthakind-DX Syrup Sugar Free',
#    'id': 149334,
#    'sku_id': 149334,
#    'available': True,
#    'pack_size_label': 'bottle of 60 ml Syrup',
#    'rx_required': {'header': 'Prescription Required',
#     'icon_url': 'https://onemg.gumlet.io/image/upload/w_20,h_20/q_auto,f_auto/rx_icon.png'},
#    'slug': '/drugs/asthakind-dx-syrup-sugar-free-149334',
#    'short_composition': 'Phenylephrine (5mg/5ml) + Chlorpheniramine Maleate (2mg/5ml) + Dextromethorphan Hydrobromide (15mg/5ml)',
#    'image_url': 'https://onemg.gumlet.io/image/upload/a_ignore,w_380,h_380,c_fit,q_auto,f_auto/v1621253360/ggfmxw9cxcghbxpxhgkz.jpg',
#    'in_stock': {'add': {'action_label': 'Adding..',
#      'final_label': 'ADDED',
#      'label': 'ADD'},
#     'cart_actions': {'dweb': ['add'], 'mweb': ['add']}},
#    'quantity': 1},
#   {'is_discontinued': False,
#    'manufacturer_name': 'Alembic Pharmaceuticals Ltd',
#    'type': 'allopathy',
#    'price': 51.7,
#    'name': 'Azithral 200 Liquid',
#    'id': 134462,
#    'sku_id': 134462,
#    'available': True,
#    'pack_size_label': 'bottle of 15 ml Oral Suspension',
#    'rx_required': {'header': 'Prescription Required',
#     'icon_url': 'https://onemg.gumlet.io/image/upload/w_20,h_20/q_auto,f_auto/rx_icon.png'},
#    'slug': '/drugs/azithral-200-liquid-134462',
#    'short_composition': 'Azithromycin (200mg/5ml)',
#    'image_url': 'https://onemg.gumlet.io/image/upload/a_ignore,w_380,h_380,c_fit,q_auto,f_auto/v1525952710/zstzbmfxqxarvwvsdz1o.jpg',
#    'in_stock': {'add': {'action_label': 'Adding..',
#      'final_label': 'ADDED',
#      'label': 'ADD'},
#     'cart_actions': {'dweb': ['add'], 'mweb': ['add']}},
#    'quantity': 1},
#   {'is_discontinued': False,
#    'manufacturer_name': 'Lupin Ltd',
#    'type': 'allopathy',
#    'price': 24.7,
#    'name': 'Akt 4 Kit',
#    'id': 138868,
#    'sku_id': 138868,
#    'available': False,
#    'pack_size_label': 'packet of 1 Kit',
#    'rx_required': {'header': 'Prescription Required',
#     'icon_url': 'https://onemg.gumlet.io/image/upload/w_20,h_20/q_auto,f_auto/rx_icon.png'},
#    'slug': '/drugs/akt-4-kit-138868',
#    'short_composition': 'Isoniazid (300mg) + Rifampicin (450mg) + Ethambutol (800mg) + Pyrazinamide (750mg)',
#    'image_url': 'https://onemg.gumlet.io/image/upload/a_ignore,w_380,h_380,c_fit,q_auto,f_auto/v1534916806/bif1zzkukawa7lcxikxk.jpg',
#    'in_stock': None,
#    'quantity': 1},
#   {'is_discontinued': True,
#    'manufacturer_name': 'Mankind Pharma Ltd',
#    'type': 'allopathy',
#    'price': 27.1,
#    'name': 'Amlokind-AT Tablet',
#    'id': 63264,
#    'sku_id': 63264,
#    'available': False,
#    'pack_size_label': 'strip of 10 tablets',
#    'rx_required': {'header': 'Prescription Required',
#     'icon_url': 'https://onemg.gumlet.io/image/upload/w_20,h_20/q_auto,f_auto/rx_icon.png'},
#    'slug': '/drugs/amlokind-at-tablet-63264',
#    'short_composition': 'Amlodipine (5mg) + Atenolol (50mg)',
#    'image_url': 'https://onemg.gumlet.io/image/upload/a_ignore,w_380,h_380,c_fit,q_auto,f_auto/v1537725269/pwud1xst8qvmftwfvrhl.jpg',
#    'in_stock': None,
#    'quantity': 10},
#   {'is_discontinued': False,
#    'manufacturer_name': 'Abbott',
#    'type': 'allopathy',
#    'price': 370.74,
#    'name': 'Arachitol 6L Injection',
#    'id': 323178,
#    'sku_id': 323178,
#    'available': True,
#    'pack_size_label': 'packet of 6 injections',
#    'rx_required': {'header': 'Prescription Required',
#     'icon_url': 'https://onemg.gumlet.io/image/upload/w_20,h_20/q_auto,f_auto/rx_icon.png'},
#    'slug': '/drugs/arachitol-6l-injection-323178',
#    'short_composition': 'Vitamin D3 (600000IU)',
#    'image_url': 'https://onemg.gumlet.io/image/upload/a_ignore,w_380,h_380,c_fit,q_auto,f_auto/v1535629110/zf2dznpliglqlagodwz4.jpg',
#    'in_stock': {'add': {'action_label': 'Adding..',
#      'final_label': 'ADDED',
#      'label': 'ADD'},
#     'cart_actions': {'dweb': ['add'], 'mweb': ['add']}},
#    'quantity': 6},
#   {'is_discontinued': False,
#    'manufacturer_name': 'Cadila Pharmaceuticals Ltd',
#    'type': 'allopathy',
#    'price': 8.1,
#    'name': 'Albendazole 400mg Tablet',
#    'id': 543127,
#    'sku_id': 543127,
#    'available': False,
#    'pack_size_label': 'strip of 1 Tablet',
#    'rx_required': {'header': 'Prescription Required',
#     'icon_url': 'https://onemg.gumlet.io/image/upload/w_20,h_20/q_auto,f_auto/rx_icon.png'},
#    'slug': '/drugs/albendazole-400mg-tablet-543127',
#    'short_composition': 'Albendazole (400mg)',
#    'image_url': 'https://onemg.gumlet.io/image/upload/a_ignore,w_380,h_380,c_fit,q_auto,f_auto/v1625228213/hx2gxivwmeoxxxsc1hix.png',
#    'in_stock': None,
#    'quantity': 1},
#   {'is_discontinued': False,
#    'manufacturer_name': 'Alkem Laboratories Ltd',
#    'type': 'allopathy',
#    'price': 72.46,
#    'name': 'Almox 500 Capsule',
#    'id': 69344,
#    'sku_id': 69344,
#    'available': True,
#    'pack_size_label': 'strip of 10 capsules',
#    'rx_required': {'header': 'Prescription Required',
#     'icon_url': 'https://onemg.gumlet.io/image/upload/w_20,h_20/q_auto,f_auto/rx_icon.png'},
#    'slug': '/drugs/almox-500-capsule-69344',
#    'short_composition': 'Amoxycillin (500mg)',
#    'image_url': 'https://onemg.gumlet.io/image/upload/a_ignore,w_380,h_380,c_fit,q_auto,f_auto/v1621258212/zt0lazekxax2krpqofen.jpg',
#    'in_stock': {'add': {'action_label': 'Adding..',
#      'final_label': 'ADDED',
#      'label': 'ADD'},
#     'cart_actions': {'dweb': ['add'], 'mweb': ['add']}},
#    'quantity': 10},
#   {'is_discontinued': False,
#    'manufacturer_name': "Dr Reddy's Laboratories Ltd",
#    'type': 'allopathy',
#    'price': 625.25,
#    'name': 'Alfoo 10mg Tablet PR',
#    'id': 131698,
#    'sku_id': 131698,
#    'available': True,
#    'pack_size_label': 'strip of 30 Tablet pr',
#    'rx_required': {'header': 'Prescription Required',
#     'icon_url': 'https://onemg.gumlet.io/image/upload/w_20,h_20/q_auto,f_auto/rx_icon.png'},
#    'slug': '/drugs/alfoo-10mg-tablet-pr-131698',
#    'short_composition': 'Alfuzosin (10mg)',
#    'image_url': 'https://onemg.gumlet.io/image/upload/a_ignore,w_380,h_380,c_fit,q_auto,f_auto/v1532517620/whj0bmxf56jlaf0g9xxj.jpg',
#    'in_stock': {'add': {'action_label': 'Adding..',
#      'final_label': 'ADDED',
#      'label': 'ADD'},
#     'cart_actions': {'dweb': ['add'], 'mweb': ['add']}},
#    'quantity': 30}],
#  'schema': {'@context': 'https://schema.org',
#   '@type': 'ItemList',
#   'url': 'https://1mg.com/drugs-all-medicines',
#   'name': 'Medicine Index',
#   'numberOfItems': 20,
#   'itemListElement': [{'@type': 'ListItem',
#     'position': 1,
#     'url': 'https://1mg.com/drugs/ativan-2mg-tablet-236513',
#     'name': 'Ativan 2mg Tablet',
#     'image': 'https://onemg.gumlet.io/image/upload/a_ignore,w_380,h_380,c_fit,q_auto,f_auto/v1625228213/hx2gxivwmeoxxxsc1hix.png'},
#    {'@type': 'ListItem',
#     'position': 2,
#     'url': 'https://1mg.com/drugs/ascoril-d-plus-syrup-sugar-free-184611',
#     'name': 'Ascoril D Plus Syrup Sugar Free',
#     'image': 'https://onemg.gumlet.io/image/upload/a_ignore,w_380,h_380,c_fit,q_auto,f_auto/v1527057821/la9aelaydysxuaizrcd5.jpg'},
#    {'@type': 'ListItem',
#     'position': 3,
#     'url': 'https://1mg.com/drugs/alprax-0.5mg-tablet-sr-68773',
#     'name': 'Alprax 0.5mg Tablet SR',
#     'image': 'https://onemg.gumlet.io/image/upload/a_ignore,w_380,h_380,c_fit,q_auto,f_auto/v1625228213/hx2gxivwmeoxxxsc1hix.png'},
#    {'@type': 'ListItem',
#     'position': 4,
#     'url': 'https://1mg.com/drugs/ativan-1mg-tablet-322827',
#     'name': 'Ativan 1mg Tablet',
#     'image': 'https://onemg.gumlet.io/image/upload/a_ignore,w_380,h_380,c_fit,q_auto,f_auto/v1625228213/hx2gxivwmeoxxxsc1hix.png'},
#    {'@type': 'ListItem',
#     'position': 5,
#     'url': 'https://1mg.com/drugs/atarax-10mg-tablet-228392',
#     'name': 'Atarax 10mg Tablet',
#     'image': 'https://onemg.gumlet.io/image/upload/a_ignore,w_380,h_380,c_fit,q_auto,f_auto/v1625228213/hx2gxivwmeoxxxsc1hix.png'},
#    {'@type': 'ListItem',
#     'position': 6,
#     'url': 'https://1mg.com/drugs/altraday-capsule-sr-63221',
#     'name': 'Altraday Capsule SR',
#     'image': 'https://onemg.gumlet.io/image/upload/a_ignore,w_380,h_380,c_fit,q_auto,f_auto/v1537710606/tqux8ccp05qx3npvxex9.jpg'},
#    {'@type': 'ListItem',
#     'position': 7,
#     'url': 'https://1mg.com/drugs/aldactone-tablet-116839',
#     'name': 'Aldactone Tablet',
#     'image': 'https://onemg.gumlet.io/image/upload/a_ignore,w_380,h_380,c_fit,q_auto,f_auto/v1537762262/wxjxsugwqsf4khtkerag.jpg'},
#    {'@type': 'ListItem',
#     'position': 8,
#     'url': 'https://1mg.com/drugs/asthalin-100mcg-inhaler-141944',
#     'name': 'Asthalin 100mcg Inhaler',
#     'image': 'https://onemg.gumlet.io/image/upload/a_ignore,w_380,h_380,c_fit,q_auto,f_auto/v1534916806/bznpbcdsc9ae6rw5er6k.jpg'},
#    {'@type': 'ListItem',
#     'position': 9,
#     'url': 'https://1mg.com/drugs/allegra-suspension-raspberry-vanilla-114550',
#     'name': 'Allegra Suspension Raspberry & Vanilla',
#     'image': 'https://onemg.gumlet.io/image/upload/a_ignore,w_380,h_380,c_fit,q_auto,f_auto/v1583498876/st6wolbj21wbl4ckon3g.jpg'},
#    {'@type': 'ListItem',
#     'position': 10,
#     'url': 'https://1mg.com/drugs/axcer-90mg-tablet-324040',
#     'name': 'Axcer  90mg Tablet',
#     'image': 'https://onemg.gumlet.io/image/upload/a_ignore,w_380,h_380,c_fit,q_auto,f_auto/v1535629110/xewhk7iu0vmvlqmk1oha.jpg'},
#    {'@type': 'ListItem',
#     'position': 11,
#     'url': 'https://1mg.com/drugs/aciloc-rd-20-tablet-285033',
#     'name': 'Aciloc RD 20 Tablet',
#     'image': 'https://onemg.gumlet.io/image/upload/a_ignore,w_380,h_380,c_fit,q_auto,f_auto/v1528455554/fkwowuw6y6t81jsfqtx0.jpg'},
#    {'@type': 'ListItem',
#     'position': 12,
#     'url': 'https://1mg.com/drugs/aldigesic-sp-tablet-146166',
#     'name': 'Aldigesic-SP Tablet',
#     'image': 'https://onemg.gumlet.io/image/upload/a_ignore,w_380,h_380,c_fit,q_auto,f_auto/v1621253290/lyjv1ia5lgikom1diwa4.jpg'},
#    {'@type': 'ListItem',
#     'position': 13,
#     'url': 'https://1mg.com/drugs/asthakind-dx-syrup-sugar-free-149334',
#     'name': 'Asthakind-DX Syrup Sugar Free',
#     'image': 'https://onemg.gumlet.io/image/upload/a_ignore,w_380,h_380,c_fit,q_auto,f_auto/v1621253360/ggfmxw9cxcghbxpxhgkz.jpg'},
#    {'@type': 'ListItem',
#     'position': 14,
#     'url': 'https://1mg.com/drugs/azithral-200-liquid-134462',
#     'name': 'Azithral 200 Liquid',
#     'image': 'https://onemg.gumlet.io/image/upload/a_ignore,w_380,h_380,c_fit,q_auto,f_auto/v1525952710/zstzbmfxqxarvwvsdz1o.jpg'},
#    {'@type': 'ListItem',
#     'position': 15,
#     'url': 'https://1mg.com/drugs/akt-4-kit-138868',
#     'name': 'Akt 4 Kit',
#     'image': 'https://onemg.gumlet.io/image/upload/a_ignore,w_380,h_380,c_fit,q_auto,f_auto/v1534916806/bif1zzkukawa7lcxikxk.jpg'},
#    {'@type': 'ListItem',
#     'position': 16,
#     'url': 'https://1mg.com/drugs/amlokind-at-tablet-63264',
#     'name': 'Amlokind-AT Tablet',
#     'image': 'https://onemg.gumlet.io/image/upload/a_ignore,w_380,h_380,c_fit,q_auto,f_auto/v1537725269/pwud1xst8qvmftwfvrhl.jpg'},
#    {'@type': 'ListItem',
#     'position': 17,
#     'url': 'https://1mg.com/drugs/arachitol-6l-injection-323178',
#     'name': 'Arachitol 6L Injection',
#     'image': 'https://onemg.gumlet.io/image/upload/a_ignore,w_380,h_380,c_fit,q_auto,f_auto/v1535629110/zf2dznpliglqlagodwz4.jpg'},
#    {'@type': 'ListItem',
#     'position': 18,
#     'url': 'https://1mg.com/drugs/albendazole-400mg-tablet-543127',
#     'name': 'Albendazole 400mg Tablet',
#     'image': 'https://onemg.gumlet.io/image/upload/a_ignore,w_380,h_380,c_fit,q_auto,f_auto/v1625228213/hx2gxivwmeoxxxsc1hix.png'},
#    {'@type': 'ListItem',
#     'position': 19,
#     'url': 'https://1mg.com/drugs/almox-500-capsule-69344',
#     'name': 'Almox 500 Capsule',
#     'image': 'https://onemg.gumlet.io/image/upload/a_ignore,w_380,h_380,c_fit,q_auto,f_auto/v1621258212/zt0lazekxax2krpqofen.jpg'},
#    {'@type': 'ListItem',
#     'position': 20,
#     'url': 'https://1mg.com/drugs/alfoo-10mg-tablet-pr-131698',
#     'name': 'Alfoo 10mg Tablet PR',
#     'image': 'https://onemg.gumlet.io/image/upload/a_ignore,w_380,h_380,c_fit,q_auto,f_auto/v1532517620/whj0bmxf56jlaf0g9xxj.jpg'}]},
#  'header_info': {'header': 'Medicine Index starting with - A'},
#  'meta_data': {'title': 'Get List of All Medicines Starting with Alphabet A at Single Place.',
#   'description': 'This Page helps to get all the medicines starting with A at single place. You can browse medicine with Alphabet A in an easy and convenient way.'}}

# %% [markdown]
# ### Stuff to record for each card -
#
# 1. Id and Skuid (for future fetching of data)
#
# 2. Name
#
# 3. Prescription req
#
# 4. is_discontinued
#
# 5. manufacturer
#
# 6. Type
#
# 7. Pack size
#
# 8. short_composition
#
# 9. rx_required.header

# %%
pd.DataFrame({str(i['id']):(str(i['sku_id']),i['name'],i['manufacturer_name'],
  i['type'],i['pack_size_label'],str(i['price']),
  i.get('rx_required'),
  i['short_composition'],str(i['is_discontinued'])) for i in extract_json(soup)['skus']}).T
# Out:
#              0                                       1  \
# 236513  236513                       Ativan 2mg Tablet
# 184611  184611         Ascoril D Plus Syrup Sugar Free
# 68773    68773                  Alprax 0.5mg Tablet SR
# 322827  322827                       Ativan 1mg Tablet
# 228392  228392                      Atarax 10mg Tablet
# 63221    63221                     Altraday Capsule SR
# 116839  116839                        Aldactone Tablet
# 141944  141944                 Asthalin 100mcg Inhaler
# 114550  114550  Allegra Suspension Raspberry & Vanilla
# 324040  324040                      Axcer  90mg Tablet
# 285033  285033                     Aciloc RD 20 Tablet
# 146166  146166                     Aldigesic-SP Tablet
# 149334  149334           Asthakind-DX Syrup Sugar Free
# 134462  134462                     Azithral 200 Liquid
# 138868  138868                               Akt 4 Kit
# 63264    63264                      Amlokind-AT Tablet
# 323178  323178                  Arachitol 6L Injection
# 543127  543127                Albendazole 400mg Tablet
# 69344    69344                       Almox 500 Capsule
# 131698  131698                    Alfoo 10mg Tablet PR
#
#                                         2          3  \
# 236513                         Pfizer Ltd  allopathy
# 184611       Glenmark Pharmaceuticals Ltd  allopathy
# 68773         Torrent Pharmaceuticals Ltd  allopathy
# 322827                         Pfizer Ltd  allopathy
# 228392        Dr Reddy's Laboratories Ltd  allopathy
# 63221   Sun Pharmaceutical Industries Ltd  allopathy
# 116839              RPG Life Sciences Ltd  allopathy
# 141944                          Cipla Ltd  allopathy
# 114550                  Sanofi India  Ltd  allopathy
# 324040  Sun Pharmaceutical Industries Ltd  allopathy
# 285033         Cadila Pharmaceuticals Ltd  allopathy
# 146166             Alkem Laboratories Ltd  allopathy
# 149334                 Mankind Pharma Ltd  allopathy
# 134462        Alembic Pharmaceuticals Ltd  allopathy
# 138868                          Lupin Ltd  allopathy
# 63264                  Mankind Pharma Ltd  allopathy
# 323178                             Abbott  allopathy
# 543127         Cadila Pharmaceuticals Ltd  allopathy
# 69344              Alkem Laboratories Ltd  allopathy
# 131698        Dr Reddy's Laboratories Ltd  allopathy
#
#                                        4       5  \
# 236513               strip of 30 tablets   82.99
# 184611            bottle of 100 ml Syrup     118
# 68773              strip of 15 tablet sr   60.85
# 322827               strip of 30 tablets   68.36
# 228392               strip of 15 tablets   43.56
# 63221             strip of 10 capsule sr     120
# 116839               strip of 15 tablets   31.95
# 141944         packet of 200 MDI Inhaler  142.51
# 114550  bottle of 100 ml Oral Suspension  188.78
# 324040               strip of 14 tablets     420
# 285033               strip of 10 tablets    42.7
# 146166               strip of 10 tablets     115
# 149334             bottle of 60 ml Syrup      64
# 134462   bottle of 15 ml Oral Suspension    51.7
# 138868                   packet of 1 Kit    24.7
# 63264                strip of 10 tablets    27.1
# 323178            packet of 6 injections  370.74
# 543127                 strip of 1 Tablet     8.1
# 69344               strip of 10 capsules   72.46
# 131698             strip of 30 Tablet pr  625.25
#
#                                                         6  \
# 236513  {'header': 'Prescription Required', 'icon_url'...
# 184611  {'header': 'Prescription Required', 'icon_url'...
# 68773   {'header': 'Prescription Required', 'icon_url'...
# 322827  {'header': 'Prescription Required', 'icon_url'...
# 228392  {'header': 'Prescription Required', 'icon_url'...
# 63221   {'header': 'Prescription Required', 'icon_url'...
# 116839  {'header': 'Prescription Required', 'icon_url'...
# 141944  {'header': 'Prescription Required', 'icon_url'...
# 114550  {'header': 'Prescription Required', 'icon_url'...
# 324040  {'header': 'Prescription Required', 'icon_url'...
# 285033  {'header': 'Prescription Required', 'icon_url'...
# 146166  {'header': 'Prescription Required', 'icon_url'...
# 149334  {'header': 'Prescription Required', 'icon_url'...
# 134462  {'header': 'Prescription Required', 'icon_url'...
# 138868  {'header': 'Prescription Required', 'icon_url'...
# 63264   {'header': 'Prescription Required', 'icon_url'...
# 323178  {'header': 'Prescription Required', 'icon_url'...
# 543127  {'header': 'Prescription Required', 'icon_url'...
# 69344   {'header': 'Prescription Required', 'icon_url'...
# 131698  {'header': 'Prescription Required', 'icon_url'...
#
#                                                         7      8
# 236513                                    Lorazepam (2mg)  False
# 184611  Phenylephrine (5mg) + Chlorpheniramine Maleate...  False
# 68773                                  Alprazolam (0.5mg)  False
# 322827                                    Lorazepam (1mg)  False
# 228392                                 Hydroxyzine (10mg)  False
# 63221            Aceclofenac (200mg) + Rabeprazole (20mg)  False
# 116839                              Spironolactone (25mg)  False
# 141944                                Salbutamol (100mcg)  False
# 114550                            Fexofenadine (30mg/5ml)  False
# 324040                                  Ticagrelor (90mg)  False
# 285033             Domperidone (10mg) + Omeprazole (20mg)   True
# 146166  Aceclofenac (100mg) + Paracetamol (325mg) + Se...  False
# 149334  Phenylephrine (5mg/5ml) + Chlorpheniramine Mal...  False
# 134462                           Azithromycin (200mg/5ml)  False
# 138868  Isoniazid (300mg) + Rifampicin (450mg) + Etham...  False
# 63264                  Amlodipine (5mg) + Atenolol (50mg)   True
# 323178                              Vitamin D3 (600000IU)  False
# 543127                                Albendazole (400mg)  False
# 69344                                 Amoxycillin (500mg)  False
# 131698                                   Alfuzosin (10mg)  False

# %%
extract_json(soup)['skus'][0].get('rx_required')['header']
# Out:
# 'Prescription Required'
